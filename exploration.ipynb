# %%
import pandas as pd
from IPython.display import display, HTML

# %%
data = pd.read_csv("datasets/dataset_min6.csv", index_col=0)
display(data.head())
# Out:
#    0_deaths  0_gold  0_gold_per_min  0_gold_spent  0_hero_healing  0_kills  \
# 0       NaN     NaN             NaN           NaN             NaN      NaN
# 1       6.0  1007.0           398.0       16085.0             0.0      1.0
# 2      11.0   686.0           213.0        4420.0             0.0      1.0
# 3       5.0  2907.5           408.5       11462.5             0.0      6.5
# 4       8.5   772.0           178.0        5750.0             0.0      1.5
#
#    0_tower_damage  0_xp_per_min  1_deaths  1_gold  ...  131_xp_per_min  \
# 0             NaN           NaN       6.0  2923.5  ...      473.250000
# 1           447.0         491.0       NaN     NaN  ...      506.200000
# 2             0.0         167.0       NaN     NaN  ...      282.333333
# 3          2163.5         418.0       NaN     NaN  ...      402.666667
# 4            43.5         207.5       NaN     NaN  ...      627.000000
#
#    132_deaths     132_gold  132_gold_per_min  132_gold_spent  \
# ...

# %%
display(data['rad_won'].value_counts(True))
# Out:
# 1.0    0.520412
# 0.0    0.479588
# Name: rad_won, dtype: float64
