# %%
import pandas as pd
import requests
from IPython.display import display, HTML
from tqdm import tqdm, trange
from time import sleep
import os
from glob import glob
import json

# %% [markdown]
# # Pro players

# %% [markdown]
# ## Download PRO-players list

# %%
result = requests.get('https://api.opendota.com/api/proPlayers')

# %%
with open("data/opendota/proplayers/list.json", "w") as f:
    f.write(result.text)

# %% [markdown]
# ## Download per-user datasets

# %%
proPlayers = pd.read_json("data/opendota/proplayers/list.json")
display(proPlayers.head())
# Out:
#    account_id            steamid  \
# 0       88470  76561197960354192
# 1     1296625  76561197961562352
# 2     3916428  76561197964182160
# 3     3940262  76561197964205984
# 4     4281729  76561197964547456
#
#                                               avatar  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...
# 1  https://steamcdn-a.akamaihd.net/steamcommunity...
# 2  https://steamcdn-a.akamaihd.net/steamcommunity...
# 3  https://steamcdn-a.akamaihd.net/steamcommunity...
# 4  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                         avatarmedium  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...
# 1  https://steamcdn-a.akamaihd.net/steamcommunity...
# 2  https://steamcdn-a.akamaihd.net/steamcommunity...
# 3  https://steamcdn-a.akamaihd.net/steamcommunity...
# 4  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                           avatarfull  \
# 0  https://steamcdn-a.akamaihd.net/steamcommunity...
# 1  https://steamcdn-a.akamaihd.net/steamcommunity...
# 2  https://steamcdn-a.akamaihd.net/steamcommunity...
# 3  https://steamcdn-a.akamaihd.net/steamcommunity...
# 4  https://steamcdn-a.akamaihd.net/steamcommunity...
#
#                                           profileurl  personaname  \
# 0       https://steamcommunity.com/id/misterdurst69/         Tzy丶
# 1            https://steamcommunity.com/id/jnewsham/     Newbsham
# 2  https://steamcommunity.com/profiles/7656119796...  gigablaster
# 3              https://steamcommunity.com/id/March8/        March
# 4  https://steamcommunity.com/profiles/7656119796...     syndereN
#
#                  last_login                full_history_time  cheese  ...  \
# 0                      None 2020-04-23 03:47:06.179000+00:00       0  ...
# 1  2018-12-21T03:12:56.027Z 2020-03-28 12:09:13.041000+00:00       0  ...
# 2                      None 2020-03-12 11:37:28.695000+00:00       0  ...
# 3                      None 2020-04-23 07:23:00.312000+00:00       0  ...
# 4                      None 2020-04-19 02:28:57.402000+00:00       0  ...
#
#    plus      name country_code  fantasy_role  team_id     team_name  team_tag  \
# 0   1.0       TZY           cn             1  6020739
# 1   1.0   Newsham                          2  6904594     TEAM TEAM        tt
# 2   NaN       EGM           se             2  7428719       GODSENT   GODSENT
# 3   1.0     March                          2  2108395  TNC Predator       TNC
# 4   1.0  syndereN                          2        0    Anti-MagE-      A-M-
#
#    is_locked is_pro locked_until
# 0      False   True          NaN
# 1       True   True          NaN
# 2       True   True          NaN
# 3       True   True          NaN
# 4       True   True          NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Download pro-player matches history

# %%
with tqdm(total=len(proPlayers)) as pbar: 
    for _, player in proPlayers.iterrows():
        account_id = player['account_id']
        url = f"https://api.opendota.com/api/players/{account_id}/matches"
        filename = f"data/opendota/proplayers/pro_players/{account_id}.json"
        
        if os.path.exists(filename):
            pbar.update(1)
            continue
        
        while (True):
            try:
                result = requests.get(url)
                if result.status_code == 200:
                    with open(filename, "w") as f:
                        f.write(result.text)
                    break
            except:
                sleep(1.0)

        pbar.update(1)
# Out:
# 100%|██████████| 1078/1078 [14:58<00:00,  1.20it/s]

# %% [markdown]
# # Pro matches

# %% [markdown]
# ## Download lists

# %%
NUM_LISTS = 100 # 100 * 100 = 10k matches

match_id = None
for i in trange(NUM_LISTS):
    url = "https://api.opendota.com/api/proMatches"
    if match_id != None:
        url = f"{url}?less_than_match_id={match_id}"
    
    pro_matches = requests.get(url)
    
    data = pd.read_json(pro_matches.text)
    match_id = data['match_id'].min()
    
    with open(f"data/opendota/proplayers/matches_lists/{i}.json", "w") as f:
        f.write(pro_matches.text)
        
    # 60 calls / minute
    sleep(1)
# Out:
# 100%|██████████| 100/100 [02:18<00:00,  1.39s/it]

# %% [markdown]
# ## Merge lists

# %%
files = glob("data/opendota/proplayers/matches_lists/*")

joined_df = pd.DataFrame()
for file in files:
    data = pd.read_json(file)
    
    joined_df = joined_df.append(data, ignore_index=True)
    
joined_df.to_csv("data/opendota/proplayers/promatches.csv", index=False)

# %% [markdown]
# ## Download matches

# %%
matches_list = pd.read_csv("data/opendota/proplayers/promatches.csv")
display(matches_list.head())
# Out:
#      match_id  duration           start_time  radiant_team_id  \
# 0  5307673835      1321  2020-03-22 14:43:25        7748848.0
# 1  5307672307      1568  2020-03-22 14:42:46        5211276.0
# 2  5307670528      3433  2020-03-22 14:42:00        7764709.0
# 3  5307616134       648  2020-03-22 14:18:44        7528248.0
# 4  5307609261      1493  2020-03-22 14:15:31        7359442.0
#
#        radiant_name  dire_team_id      dire_name  leagueid  \
# 0            AsghaR     7787796.0      LEGENDARY     11439
# 1           Thunder     6593779.0      Gentlemen     11439
# 2            BeWare           NaN            NaN     11439
# 3          Manaburn     7715060.0         WOLVES     11478
# 4  Team Aspirations     7314697.0  FIVE BROTHERS     11249
#
#                          league_name  series_id  series_type  radiant_score  \
# 0         PESC Monthly 2020 Season 1     419196            0             26
# 1         PESC Monthly 2020 Season 1     419194            0             42
# 2         PESC Monthly 2020 Season 1          0            0             36
# 3  YouTube SIVVIT - Big Russian Show     419183            0             15
# 4                       RED STAR CUP     419159            1             40
#
#    dire_score  radiant_win
# 0           6         True
# 1           8         True
# 2          37        False
# 3           7         True
# 4          30         True

# %%
with tqdm(total=len(matches_list)) as pbar: 
    for _, match in matches_list.iterrows():
        match_id = match['match_id']
        url = f"https://api.opendota.com/api/matches/{match_id}"
        filename = f"data/opendota/proplayers/pro_matches/{match_id}.json"
        
        if os.path.exists(filename):
            pbar.update(1)
            continue
        
        while (True):
            try:
                result = requests.get(url)
                if result.status_code == 200:
                    with open(filename, "w") as f:
                        f.write(result.text)
                    break
            except:
                sleep(1.0)

        pbar.update(1)
# Out:
# 100%|██████████| 10000/10000 [2:52:05<00:00,  1.03s/it]

# %% [markdown]
# ## Merge matches
